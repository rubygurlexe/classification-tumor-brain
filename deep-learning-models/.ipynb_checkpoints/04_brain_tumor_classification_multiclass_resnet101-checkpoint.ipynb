# %% [markdown]
# ## Importing the necessary libraries

# %%
import os
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.image import imread
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, BatchNormalization, Flatten, Dropout
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.applications.resnet import ResNet101, preprocess_input
from tensorflow.keras.optimizers import Adam 
from tensorflow.keras.preprocessing import image

# %% [markdown]
# ## Getting the path of the training and testing data of the brain tumor dataset

# %%
dataset_directory_location = 'Dataset'

# %%
os.listdir(dataset_directory_location)
# Out:
# ['Testing', 'Training']

# %%
train_dataset_location = os.path.join(dataset_directory_location, 'Training')
test_dataset_location = os.path.join(dataset_directory_location, 'Testing')

# %%
os.listdir(train_dataset_location)
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
os.listdir(test_dataset_location)
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %% [markdown]
# ## Viewing a brain image

# %%
brain_img_glicoma = os.path.join(train_dataset_location, 'glioma')

# %%
os.listdir(brain_img_glicoma)[:1]
# Out:
# ['Tr-glTr_0000.jpg']

# %%
brain_img_glicoma_read = imread(os.path.join(brain_img_glicoma, 'Tr-gl_0010.jpg'))

# %%
plt.imshow(brain_img_glicoma_read)

# %%
brain_img_glicoma_read.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# ## Defining the correct shape of the image

# %%
correct_image_shape = (224, 224, 3)

# %% [markdown]
# ## Defining the ImageGenerator and performing Data Augmentation

# %%
image_gen = ImageDataGenerator(rotation_range=20, 
                               width_shift_range=0.1, 
                               height_shift_range=0.1, 
                               shear_range=0.1, 
                               zoom_range=0.1, 
                               horizontal_flip=True, 
                               fill_mode='nearest',
                               preprocessing_function=preprocess_input)

# %%
train_image_gen = image_gen.flow_from_directory(train_dataset_location, 
                                                target_size=correct_image_shape[:2], 
                                                color_mode='rgb', 
                                                batch_size=16, 
                                                class_mode='categorical')

test_image_gen = image_gen.flow_from_directory(test_dataset_location, 
                                                target_size=correct_image_shape[:2], 
                                                color_mode='rgb', 
                                                batch_size=16, 
                                                class_mode='categorical')
# Out:
# Found 5369 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.

# %% [markdown]
# ## Defining the early stop

# %%
early_stop_loss = EarlyStopping(monitor='loss', patience=2)
early_stop_val_loss = EarlyStopping(monitor='val_loss', patience=2)

# %% [markdown]
# ## Creating and training the model

# %%
model = Sequential()

# %%
resnet101_model = ResNet101(weights='imagenet', include_top=False, input_shape=correct_image_shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 ━━━━━━━━━━━━━━━━━━━━ 71s 0us/step

# %%
resnet101_model.trainable = False

# %%
model.add(resnet101_model)

model.add(Flatten())

model.add(BatchNormalization())

model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())

model.add(Dropout(0.3))

model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())

model.add(Dropout(0.3))

model.add(Dense(4, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet101 (Functional)          │ ?                      │    42,658,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 42,658,176 (162.73 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 42,658,176 (162.73 MB)

# %%
model.compile(loss=CategoricalCrossentropy(), optimizer=Adam(learning_rate=0.00001), metrics=['accuracy'])

# %%
model.fit(train_image_gen, validation_data=test_image_gen, epochs=30, callbacks=[early_stop_loss, early_stop_val_loss])
# Out:
# Epoch 1/30
# c:\Users\shafi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 1132s 3s/step - accuracy: 0.5613 - loss: 1.1286 - val_accuracy: 0.7796 - val_loss: 0.6087
# Epoch 2/30
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 1061s 3s/step - accuracy: 0.7626 - loss: 0.6371 - val_accuracy: 0.8268 - val_loss: 0.4611
# Epoch 3/30
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 1270s 4s/step - accuracy: 0.8092 - loss: 0.5349 - val_accuracy: 0.8490 - val_loss: 0.4241
# Epoch 4/30
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 1176s 3s/step - accuracy: 0.8196 - loss: 0.4780 - val_accuracy: 0.8642 - val_loss: 0.3771
# Epoch 5/30
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 1159s 3s/step - accuracy: 0.8503 - loss: 0.4200 - val_accuracy: 0.8688 - val_loss: 0.3507
# Epoch 6/30
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 1167s 3s/step - accuracy: 0.8537 - loss: 0.4256 - val_accuracy: 0.8719 - val_loss: 0.3281
# Epoch 7/30
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 1087s 3s/step - accuracy: 0.8550 - loss: 0.4009 - val_accuracy: 0.8848 - val_loss: 0.3113
# Epoch 8/30
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 1090s 3s/step - accuracy: 0.8667 - loss: 0.3842 - val_accuracy: 0.8909 - val_loss: 0.3056
# Epoch 9/30
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 1082s 3s/step - accuracy: 0.8827 - loss: 0.3441 - val_accuracy: 0.9024 - val_loss: 0.2720
# Epoch 10/30
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 1048s 3s/step - accuracy: 0.8924 - loss: 0.3300 - val_accuracy: 0.9054 - val_loss: 0.2546
# Epoch 11/30
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 1054s 3s/step - accuracy: 0.8885 - loss: 0.3328 - val_accuracy: 0.9092 - val_loss: 0.2541
# Epoch 12/30
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 988s 3s/step - accuracy: 0.8913 - loss: 0.3194 - val_accuracy: 0.9047 - val_loss: 0.2610
# Epoch 13/30
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 995s 3s/step - accuracy: 0.8984 - loss: 0.2992 - val_accuracy: 0.9138 - val_loss: 0.2417
# Epoch 14/30
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 987s 3s/step - accuracy: 0.8975 - loss: 0.3044 - val_accuracy: 0.9184 - val_loss: 0.2127
# Epoch 15/30
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 979s 3s/step - accuracy: 0.9031 - loss: 0.2821 - val_accuracy: 0.9214 - val_loss: 0.2110
# Epoch 16/30
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 991s 3s/step - accuracy: 0.8961 - loss: 0.2918 - val_accuracy: 0.9283 - val_loss: 0.2079
# Epoch 17/30
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 1011s 3s/step - accuracy: 0.8910 - loss: 0.3148 - val_accuracy: 0.9283 - val_loss: 0.2024
# Epoch 18/30
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 1227s 4s/step - accuracy: 0.9110 - loss: 0.2578 - val_accuracy: 0.9306 - val_loss: 0.1929
# Epoch 19/30
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 1847s 5s/step - accuracy: 0.9001 - loss: 0.2836 - val_accuracy: 0.9344 - val_loss: 0.1886
# Epoch 20/30
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 1911s 6s/step - accuracy: 0.9188 - loss: 0.2474 - val_accuracy: 0.9428 - val_loss: 0.1805

# %%
history_df = pd.DataFrame(model.history.history)

# %%
history_df[['loss', 'val_loss']].plot()
# Out:
# <AxesSubplot: >

# %%
history_df[['accuracy', 'val_accuracy']].plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Evaluating the model

# %%
model.evaluate(train_image_gen)[1]
# Out:
# 336/336 ━━━━━━━━━━━━━━━━━━━━ 886s 3s/step - accuracy: 0.9673 - loss: 0.1164
# 0.9661017060279846

# %%
model.evaluate(test_image_gen)[1]
# Out:
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 210s 3s/step - accuracy: 0.9337 - loss: 0.1906
# 0.9313501119613647

# %% [markdown]
# ## Predicting on a sample image

# %%
sample_img_load = image.load_img('./Dataset/Testing/pituitary/Te-piTr_0003.jpg', target_size=correct_image_shape)

# %%
sample_img_load
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
sample_img_to_arr = image.img_to_array(sample_img_load)

# %%
sample_img_to_arr = preprocess_input(sample_img_to_arr)

# %%
sample_img_to_arr_expand_dim = np.expand_dims(sample_img_to_arr, 0)

# %%
prediction = model.predict(sample_img_to_arr_expand_dim)[0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step

# %%
pred_result = np.argmax(prediction)

# %%
class_names = ['glioma', 'meningioma', 'no tumor', 'pituitary']

# %%
pred_final_result = class_names[pred_result]

# %%
pred_final_result
# Out:
# 'pituitary'

# %% [markdown]
# ## Saving the model

# %%
model.save('resnet101_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
